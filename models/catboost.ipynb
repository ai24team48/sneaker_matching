# %%
import pandas as pd 
import numpy as np
import json
import ast
from catboost import CatBoostClassifier
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
import os
from dotenv import load_dotenv
from scipy.spatial.distance import euclidean
from sklearn.metrics import pairwise_distances
from sklearn.metrics.pairwise import cosine_distances, euclidean_distances, manhattan_distances




load_dotenv()
# Out:
# True

# %% [markdown]
# ## Reading data

# %%
PATH = os.getenv("DATA_PATH")
attributes_df = pd.read_parquet(PATH + "attributes.parquet")
resnet_df = pd.read_parquet(PATH + "resnet.parquet")
text_and_bert_df = pd.read_parquet(PATH + "text_and_bert.parquet")
train_pairs_df = pd.read_parquet(PATH + "train.parquet")
test_pairs_db = pd.read_parquet(PATH + "test.parquet")

# %%
train_pairs_df.head()
# Out:
#    variantid1  variantid2  target
# 0  1447875869  1447872068       1
# 1  1176231201   284733670       1
# 2   658617865   549848659       0
# 3   719320625   719370486       1
# 4  1067645658   949954740       0

# %%
attributes_df.head()
# Out:
#    variantid                                         categories  \
# 0   47920382  {"1": "EPG", "2": "Детские товары", "3": "Игру...
# 1   49801845  {"1": "EPG", "2": "Хобби и творчество", "3": "...
# 2   49853444  {"1": "EPG", "2": "Хобби и творчество", "3": "...
# 3   49893028  {"1": "EPG", "2": "Хобби и творчество", "3": "...
# 4   49987483  {"1": "EPG", "2": "Хобби и творчество", "3": "...
#
#                    characteristic_attributes_mapping
# 0  {"Цвет товара": ["бежевый", "светло-розовый"],...
# 1  {"Количество в упаковке, шт": ["1"], "Бренд": ...
# 2  {"Бренд": ["Vervaco"], "Тип": ["Набор для выши...
# 3  {"Цвет товара": ["серый"], "Ширина, см": ["0.8...
# 4  {"Цвет товара": ["разноцветный"], "Название цв...

# %%
def split_cat_product(json_data):
    try:
        categories = json.loads(json_data)
        return [categories.get(str(i), None) for i in range(1, 5)]
    except json.JSONDecodeError:
        print(f"Error decoding JSON: {json_data}")
        return [None] * 4

attributes_df[["cat_level_1", "cat_level_2", "cat_level_3", "cat_level_4"]] = attributes_df["categories"].apply(
    lambda x: pd.Series(split_cat_product(x))
)

# %%
attributes_df.head()
# Out:
#    variantid                                         categories  \
# 0   47920382  {"1": "EPG", "2": "Детские товары", "3": "Игру...
# 1   49801845  {"1": "EPG", "2": "Хобби и творчество", "3": "...
# 2   49853444  {"1": "EPG", "2": "Хобби и творчество", "3": "...
# 3   49893028  {"1": "EPG", "2": "Хобби и творчество", "3": "...
# 4   49987483  {"1": "EPG", "2": "Хобби и творчество", "3": "...
#
#                    characteristic_attributes_mapping cat_level_1  \
# 0  {"Цвет товара": ["бежевый", "светло-розовый"],...         EPG
# 1  {"Количество в упаковке, шт": ["1"], "Бренд": ...         EPG
# 2  {"Бренд": ["Vervaco"], "Тип": ["Набор для выши...         EPG
# 3  {"Цвет товара": ["серый"], "Ширина, см": ["0.8...         EPG
# 4  {"Цвет товара": ["разноцветный"], "Название цв...         EPG
#
#           cat_level_2                      cat_level_3  \
# 0      Детские товары                          Игрушки
# 1  Хобби и творчество           Материал для рукоделия
# 2  Хобби и творчество  Набор для рукоделия, творчества
# 3  Хобби и творчество                     Нитки, пряжа
# 4  Хобби и творчество      Настольные и карточные игры
#
#                        cat_level_4
# 0               Игрушка для ванной
# 1        Стеклярус, бусины, стразы
# 2              Набор для вышивания
# 3  Тесьма, кружево, лента, резинка
# 4                  Настольная игра

# %%
def join_attrib_by_pare(pairs_df:pd.DataFrame):
    features_df = (
        pairs_df
        .merge(
            attributes_df
            .add_suffix('1'),
            on="variantid1"
        )
        .merge(
            attributes_df
            .add_suffix('2'),
            on="variantid2"
        )
    )
    features_df = (
        features_df
        .merge(
            text_and_bert_df
            .add_suffix('1'),
            on="variantid1"
        )
        .merge(
            text_and_bert_df
            .add_suffix('2'),
            on="variantid2"
        )
    )
    features_df = (
        features_df
        .merge(
            resnet_df
            .add_suffix('1'),
            on="variantid1"
        )
        .merge(
            resnet_df
            .add_suffix('2'),
            on="variantid2"
        )
    )
    return features_df
    
train_features_df = join_attrib_by_pare(train_pairs_df)

train_features_df.shape
# Out:
# (1168516, 25)

# %%
train_features_df.head()
# Out:
#    variantid1  variantid2  target  \
# 0  1447875869  1447872068       1
# 1  1176231201   284733670       1
# 2   658617865   549848659       0
# 3   719320625   719370486       1
# 4  1067645658   949954740       0
#
#                                          categories1  \
# 0  {"1": "Одежда и обувь", "2": "Одежда", "3": "О...
# 1  {"1": "EPG", "2": "Товары для взрослых", "3": ...
# 2  {"1": "EPG", "2": "Товары для животных", "3": ...
# 3  {"1": "EPG", "2": "Строительство и ремонт", "3...
# 4  {"1": "EPG", "2": "Канцелярские товары", "3": ...
#
#                   characteristic_attributes_mapping1    cat_level_11  \
# 0  {"Серия в одежде и обуви": ["Harper's Bazaar (...  Одежда и обувь
# 1  {"Тип фиксатора БДСМ": ["Наручники"], "Вибраци...             EPG
# 2  {"Артикул": ["83809"], "Комплектация": ["Сухой...             EPG
# 3  {"Комплектация": ["Бур 310 мм, 1 штука."], "Цв...             EPG
# 4  {"Комплектация": ["Товар поставляется в упаков...             EPG
#
#              cat_level_21                         cat_level_31  \
# 0                  Одежда                               Одежда
# 1     Товары для взрослых                                 БДСМ
# 2     Товары для животных  Корма и лакомства для кошек и собак
# 3  Строительство и ремонт           Расходники для инструмента
# 4     Канцелярские товары                                Пенал
#
#                cat_level_41  \
# 0           Свитер, джемпер
# 1     Наручники и фиксаторы
# 2                Корм сухой
# 3  Бур, сверло, набор сверл
# 4                     Пенал
#
#                                          categories2  ...  \
# 0  {"1": "Одежда и обувь", "2": "Одежда", "3": "О...  ...
# 1  {"1": "EPG", "2": "Товары для взрослых", "3": ...  ...
# 2  {"1": "EPG", "2": "Товары для животных", "3": ...  ...
# 3  {"1": "EPG", "2": "Строительство и ремонт", "3...  ...
# 4  {"1": "EPG", "2": "Канцелярские товары", "3": ...  ...
#
#                                                name1  \
# 0             Свитер Uniqlo Harper's Bazaar (журнал)
# 1   Ремень для фиксации предплечий к запястьям Джага
# 2  Сухой корм Hill's Science Plan для кошек с кур...
# 3                      Бур SDS-plus 20х310мм ELITECH
# 4  Пенал-тубус мягкий 65x210 мм, ПТ-22 "Кошачьи л...
#
#                                         description1  \
# 0                                               None
# 1  Фиксатор поможет правильно зафиксировать партн...
# 2  Сухой корм Hill&#39;s Science Plan для взрослы...
# 3  Бур Elitech используется в перфораторах с патр...
# 4  Материал: Металл, пластик, текстиль<br/> Габар...
#
#                                        name_bert_641  \
# 0  [-0.3927455246448517, 0.4909455478191376, 0.56...
# 1  [-0.5404430627822876, 0.31526750326156616, 0.3...
# 2  [-0.4767049252986908, 0.5492467880249023, 0.41...
# 3  [-0.6116019487380981, 0.4067917764186859, 0.54...
# 4  [-0.6164239048957825, 0.6769619584083557, 0.73...
#
#                                                name2  \
# 0             Свитер Uniqlo Harper's Bazaar (журнал)
# 1  Ремень для фиксации предплечий к запястьям Джа...
# 2  HILL'S SP Optimal Care Сухой корм д/кошек с Ку...
# 3                      Бур SDS-plus 20х310мм ELITECH
# 4  Пенал-тубус мягкий 65 х 210 мм, ПТ-22 Милая панда
#
#                                         description2  \
# 0                                               None
# 1  БДСМ, для женщин, стандартный, черный <br>мате...
# 2  \nСухой корм для взрослых кошек HILL'S SCIENCE...
# 3  Бур Elitech используется в перфораторах с патр...
# 4  Пенал-тубус мягкий 65 х 210 мм, ПТ-22 Милая панда
#
#                                        name_bert_642  \
# 0  [-0.3927455246448517, 0.4909455478191376, 0.56...
# 1  [-0.5957552790641785, 0.3414252698421478, 0.46...
# 2  [-0.26443710923194885, 0.3921107053756714, 0.5...
# 3  [-0.6116019487380981, 0.4067917764186859, 0.54...
# 4  [-0.5198364853858948, 0.6435920596122742, 0.64...
#
#                       main_pic_embeddings_resnet_v11  \
# 0  [[0.5318107604980469, 0.35363996028900146, -0....
# 1  [[0.4308440089225769, 0.7620932459831238, 0.79...
# 2  [[-0.36238163709640503, 0.4316844344139099, -0...
# 3  [[0.7327960729598999, -0.7488707900047302, 0.5...
# 4  [[-1.3140270709991455, -0.8071212768554688, 0....
#
#                            pic_embeddings_resnet_v11  \
# 0  [[0.48105278611183167, 0.6172202825546265, -0....
# 1  [[0.5668608546257019, 0.9573432803153992, 1.01...
# 2  [[-0.5063896179199219, 0.707477331161499, -0.1...
# 3                                               None
# 4  [[-1.3976482152938843, -0.6419062614440918, 0....
#
#                       main_pic_embeddings_resnet_v12  \
# 0  [[0.5318107604980469, 0.35363996028900146, -0....
# 1  [[0.5668608546257019, 0.9573432803153992, 1.01...
# 2  [[-0.25123998522758484, 0.3757574260234833, -0...
# 3  [[0.7327960729598999, -0.7488707900047302, 0.5...
# 4  [[-0.49589139223098755, -0.5760805606842041, 0...
#
#                            pic_embeddings_resnet_v12
# 0  [[0.37079137563705444, 0.21004441380500793, -0...
# 1  [[0.4432561695575714, 0.7602171301841736, 0.76...
# 2  [[-0.3037261366844177, -1.0693305730819702, 0....
# 3                                               None
# 4                                               None
#
# [5 rows x 25 columns]

# %%
train_features_df[["cat_level_1_1", "cat_level_2_1", "cat_level_3_1", "cat_level_4_1"]] = train_features_df["categories1"].apply(lambda x: pd.Series(split_cat_product(x)))
train_features_df[["cat_level_1_2", "cat_level_2_2", "cat_level_3_2", "cat_level_4_2"]] = train_features_df["categories2"].apply(lambda x: pd.Series(split_cat_product(x)))

# %%
train_features_df.head()
# Out:
#    variantid1  variantid2  target  \
# 0  1447875869  1447872068       1
# 1  1176231201   284733670       1
# 2   658617865   549848659       0
# 3   719320625   719370486       1
# 4  1067645658   949954740       0
#
#                                          categories1  \
# 0  {"1": "Одежда и обувь", "2": "Одежда", "3": "О...
# 1  {"1": "EPG", "2": "Товары для взрослых", "3": ...
# 2  {"1": "EPG", "2": "Товары для животных", "3": ...
# 3  {"1": "EPG", "2": "Строительство и ремонт", "3...
# 4  {"1": "EPG", "2": "Канцелярские товары", "3": ...
#
#                   characteristic_attributes_mapping1    cat_level_11  \
# 0  {"Серия в одежде и обуви": ["Harper's Bazaar (...  Одежда и обувь
# 1  {"Тип фиксатора БДСМ": ["Наручники"], "Вибраци...             EPG
# 2  {"Артикул": ["83809"], "Комплектация": ["Сухой...             EPG
# 3  {"Комплектация": ["Бур 310 мм, 1 штука."], "Цв...             EPG
# 4  {"Комплектация": ["Товар поставляется в упаков...             EPG
#
#              cat_level_21                         cat_level_31  \
# 0                  Одежда                               Одежда
# 1     Товары для взрослых                                 БДСМ
# 2     Товары для животных  Корма и лакомства для кошек и собак
# 3  Строительство и ремонт           Расходники для инструмента
# 4     Канцелярские товары                                Пенал
#
#                cat_level_41  \
# 0           Свитер, джемпер
# 1     Наручники и фиксаторы
# 2                Корм сухой
# 3  Бур, сверло, набор сверл
# 4                     Пенал
#
#                                          categories2  ...  \
# 0  {"1": "Одежда и обувь", "2": "Одежда", "3": "О...  ...
# 1  {"1": "EPG", "2": "Товары для взрослых", "3": ...  ...
# 2  {"1": "EPG", "2": "Товары для животных", "3": ...  ...
# 3  {"1": "EPG", "2": "Строительство и ремонт", "3...  ...
# 4  {"1": "EPG", "2": "Канцелярские товары", "3": ...  ...
#
#                       main_pic_embeddings_resnet_v12  \
# 0  [[0.5318107604980469, 0.35363996028900146, -0....
# 1  [[0.5668608546257019, 0.9573432803153992, 1.01...
# 2  [[-0.25123998522758484, 0.3757574260234833, -0...
# 3  [[0.7327960729598999, -0.7488707900047302, 0.5...
# 4  [[-0.49589139223098755, -0.5760805606842041, 0...
#
#                            pic_embeddings_resnet_v12   cat_level_1_1  \
# 0  [[0.37079137563705444, 0.21004441380500793, -0...  Одежда и обувь
# 1  [[0.4432561695575714, 0.7602171301841736, 0.76...             EPG
# 2  [[-0.3037261366844177, -1.0693305730819702, 0....             EPG
# 3                                               None             EPG
# 4                                               None             EPG
#
#             cat_level_2_1                        cat_level_3_1  \
# 0                  Одежда                               Одежда
# 1     Товары для взрослых                                 БДСМ
# 2     Товары для животных  Корма и лакомства для кошек и собак
# 3  Строительство и ремонт           Расходники для инструмента
# 4     Канцелярские товары                                Пенал
#
#               cat_level_4_1   cat_level_1_2           cat_level_2_2  \
# 0           Свитер, джемпер  Одежда и обувь                  Одежда
# 1     Наручники и фиксаторы             EPG     Товары для взрослых
# 2                Корм сухой             EPG     Товары для животных
# 3  Бур, сверло, набор сверл             EPG  Строительство и ремонт
# 4                     Пенал             EPG     Канцелярские товары
#
#                          cat_level_3_2             cat_level_4_2
# 0                               Одежда           Свитер, джемпер
# 1                                 БДСМ     Наручники и фиксаторы
# 2  Корма и лакомства для кошек и собак                Корм сухой
# 3           Расходники для инструмента  Бур, сверло, набор сверл
# 4                                Пенал                     Пенал
#
# [5 rows x 33 columns]

# %%
train_features_df["is_equal_cat_1"] = train_features_df.apply(lambda x: 1 if x["cat_level_1_1"] == x["cat_level_1_2"] else 0, axis=1)
train_features_df["is_equal_cat_2"] = train_features_df.apply(lambda x: 1 if x["cat_level_2_1"] == x["cat_level_2_2"] else 0, axis=1)
train_features_df["is_equal_cat_3"] = train_features_df.apply(lambda x: 1 if x["cat_level_3_1"] == x["cat_level_3_2"] else 0, axis=1)
train_features_df["is_equal_cat_4"] = train_features_df.apply(lambda x: 1 if x["cat_level_4_1"] == x["cat_level_4_2"] else 0, axis=1)

# %% [markdown]
# Calculate distance between pictures embeddings

# %%
train_features_df['pic_embeddings_resnet_v11'].fillna(train_features_df['main_pic_embeddings_resnet_v11'], inplace=True, axis=1)
train_features_df['pic_embeddings_resnet_v12'].fillna(train_features_df['main_pic_embeddings_resnet_v12'], inplace=True, axis=1)
# Out:
# /var/folders/pw/hlrwjnj16ygg94jb9ftq1y7h0000gn/T/ipykernel_6041/3726142081.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_features_df['pic_embeddings_resnet_v11'].fillna(train_features_df['main_pic_embeddings_resnet_v11'], inplace=True, axis=1)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/generic.py in ?(cls, axis)
#     576             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     577         except KeyError:
# --> 578             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /var/folders/pw/hlrwjnj16ygg94jb9ftq1y7h0000gn/T/ipykernel_6041/3726142081.py in ?()
# ----> 1 train_features_df['pic_embeddings_resnet_v11'].fillna(train_features_df['main_pic_embeddings_resnet_v11'], inplace=True, axis=1)
#       2 train_features_df['pic_embeddings_resnet_v12'].fillna(train_features_df['main_pic_embeddings_resnet_v12'], inplace=True, axis=1)
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/generic.py in ?(self, value, method, axis, inplace, limit, downcast)
#    7306         # set the default here, so functions examining the signaure
#    7307         # can detect if something was set (e.g. in groupby) (GH9221)
#    7308         if axis is None:
#    7309             axis = 0
# -> 7310         axis = self._get_axis_number(axis)
#    7311
#    7312         if value is None:
#    7313             return self._pad_or_backfill(
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/generic.py in ?(cls, axis)
#     574     def _get_axis_number(cls, axis: Axis) -> AxisInt:
#     575         try:
#     576             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     577         except KeyError:
# --> 578             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# ValueError: No axis named 1 for object type Series

# %%
train_features_df['pic_embeddings_resnet_v11'][0]
# Out:
# array([array([ 0.48105279,  0.61722028, -0.92956924,  0.58494997, -0.39972499,
#                0.1672667 ,  0.19093876,  0.27397907, -0.20669027,  0.20641999,
#                0.62182772,  0.49346626,  0.56302661, -0.3033376 , -0.82235485,
#               -0.35017902, -0.45489082,  0.83371705,  0.39855587, -1.31549776,
#               -0.05345596, -0.43214187,  0.58170956,  0.84533298, -0.92885989,
#                0.20570301,  0.79168326,  0.21535063, -0.18874221,  0.17430928,
#               -0.19970071, -0.19815165,  0.04007574, -0.87008858, -0.77613705,
#               -0.48179996, -0.25496256, -0.16763625,  0.38557118,  0.12529162,
#               -0.17330198,  0.62044591, -0.10199317,  0.47181588, -0.40329814,
#               -0.17897706, -0.16631064,  0.27796754,  0.34288749, -0.60033876,
#                0.12440461, -0.47554481,  1.28908658,  0.07156913, -0.40316623,
#                0.43744162, -0.14619397, -0.64844143,  0.53708351,  0.30358773,
#                0.02098434, -0.1235783 ,  0.56312048,  0.00355464, -0.15368092,
#                0.21914995, -0.49090436,  0.29252166, -0.4953517 , -0.21617641,
#                0.36629015,  0.0732475 , -0.30759421,  0.77462596, -0.96853518,
#               -0.15894151, -0.84671295, -0.44649783, -0.41949648,  0.24565825,
#               -0.12855501,  0.40862232, -0.69815624, -1.19380283, -0.08455067,
#                0.43779421, -0.19360015,  0.81197697, -0.71786606,  0.05984724,
#                0.02957335, -0.08419726,  0.06293873,  0.31219512, -0.11600161,
#                0.82504725, -0.01419856, -0.3699241 ,  1.43869996,  0.41448319,
#               -0.5043565 , -0.05723624,  0.06847006,  0.2803508 , -0.69859219,
#               -0.08062792, -0.30450341,  0.24524981, -0.15679365, -0.54275322,
#               -0.41875553,  0.32388258, -0.09484775,  0.5375464 ,  0.29414231,
#               -0.06720607,  0.27408612, -0.40818363, -1.06359923, -0.10898693,
#                0.27737212, -0.01499585,  0.50835091,  0.01270733, -0.31967291,
#               -0.08754809,  0.30764493,  0.36523014,  0.38262483, -0.23292764,
#                0.67831212, -0.07540497, -0.58938855,  1.39868259,  0.26111072,
#               -0.15919009,  0.22617424,  0.21535325,  0.16920438, -0.26112893,
#                0.93157506, -0.58074605,  0.26208621, -0.47123653, -0.1312398 ,
#               -0.11430389,  0.0317844 ,  0.42200971,  0.22483477, -0.60723174,
#                0.08391254, -0.89049512,  0.23080504, -0.17255437, -0.00362615,
#               -0.28562683,  0.03841035,  0.11653434,  0.50819802,  0.28994581,
#               -1.02262878,  0.45616761, -0.27482873])                         ],
#       dtype=object)

# %%
train_features_df['main_pic_distance'] = train_features_df.apply(
    lambda row: euclidean(row['main_pic_embeddings_resnet_v11'], row['main_pic_embeddings_resnet_v12']),
    axis=1
)

# %%
train_features_df['text_distance_cos'] = train_features_df.apply(
    lambda row: cosine_distances([row['name_bert_641']], [row['name_bert_642']]),
    axis=1
)

train_features_df['text_distance_euc'] = train_features_df.apply(
    lambda row: euclidean_distances([row['name_bert_641']], [row['name_bert_642']]),
    axis=1
)

train_features_df['text_distance_man'] = train_features_df.apply(
    lambda row: manhattan_distances([row['name_bert_641']], [row['name_bert_642']]),
    axis=1
)

# %%
total = train_features_df.shape[0]
for i in range (1,5):
    not_the_same = train_features_df[train_features_df[f'is_equal_cat_{i}']==0].shape[0]
    the_same = total - not_the_same
    print(not_the_same,the_same)
# Out:
# 102 1168414
# 484 1168032
# 45325 1123191
# 121250 1047266

# %%
category_data_1 = {}

for category in train_features_df["cat_level_1_1"].unique():
    filtered_df = attributes_df[attributes_df["cat_level_1"] == category]
    characteristics_series = filtered_df["characteristic_attributes_mapping"]
    
    key_frequencies = {}  # Словарь для подсчета частоты ключей
    value_frequencies = {}  # Словарь для подсчета частоты значений по ключам

    for characteristic_text in characteristics_series.dropna():  
        characteristic_data = json.loads(characteristic_text) 
        
        for attribute, values in characteristic_data.items():  
            if attribute not in key_frequencies:
                key_frequencies[attribute] = 0
            key_frequencies[attribute] += 1
            
            if attribute not in value_frequencies:
                value_frequencies[attribute] = {}
            
            for value in values:
                if value not in value_frequencies[attribute]:
                    value_frequencies[attribute][value] = 0
                value_frequencies[attribute][value] += 1

    category_data_1[category] = (key_frequencies, value_frequencies, len(characteristics_series.dropna()))

# Выводим результат (если нужно)
# print(category_data_1)

# %%
category_data_1.keys()
# Out:
# dict_keys(['Одежда и обувь', 'EPG', 'Книги и цифровые книги'])

# %%
category_data_2 = {}

for category in train_features_df["cat_level_2_1"].unique():
    filtered_df = attributes_df[attributes_df["cat_level_2"] == category]
    characteristics_series = filtered_df["characteristic_attributes_mapping"]
    
    key_frequencies = {}  # Словарь для подсчета частоты ключей
    value_frequencies = {}  # Словарь для подсчета частоты значений по ключам

    for characteristic_text in characteristics_series.dropna():  
        characteristic_data = json.loads(characteristic_text) 
        
        for attribute, values in characteristic_data.items():  
            if attribute not in key_frequencies:
                key_frequencies[attribute] = 0
            key_frequencies[attribute] += 1
            
            if attribute not in value_frequencies:
                value_frequencies[attribute] = {}
            
            for value in values:
                if value not in value_frequencies[attribute]:
                    value_frequencies[attribute][value] = 0
                value_frequencies[attribute][value] += 1

    category_data_2[category] = (key_frequencies, value_frequencies, len(characteristics_series.dropna()))

# Выводим результат (если нужно)
# print(category_data_2)

# %%
category_data_2.keys()
# Out:
# dict_keys(['Одежда', 'Товары для взрослых', 'Товары для животных', 'Строительство и ремонт', 'Канцелярские товары', 'Продукты питания', 'Автотовары', 'Аптека', 'Дом и сад', 'Обувь', 'Книги', 'Галантерея и аксессуары', 'Хобби и творчество', 'Мебель', 'Спорт и отдых', 'Красота и гигиена', 'Детские товары', 'Электроника', 'Бытовая техника', 'Бытовая химия', 'Антиквариат и коллекционирование', 'Ювелирные изделия', 'Фермерское хозяйство', 'Автомототехника'])

# %%
category_data_3 = {}

for category in train_features_df["cat_level_3_1"].unique():
    filtered_df = attributes_df[attributes_df["cat_level_3"] == category]
    characteristics_series = filtered_df["characteristic_attributes_mapping"]
    
    key_frequencies = {}  # Словарь для подсчета частоты ключей
    value_frequencies = {}  # Словарь для подсчета частоты значений по ключам

    for characteristic_text in characteristics_series.dropna():  
        characteristic_data = json.loads(characteristic_text) 
        
        for attribute, values in characteristic_data.items():  
            if attribute not in key_frequencies:
                key_frequencies[attribute] = 0
            key_frequencies[attribute] += 1
            
            if attribute not in value_frequencies:
                value_frequencies[attribute] = {}
            
            for value in values:
                if value not in value_frequencies[attribute]:
                    value_frequencies[attribute][value] = 0
                value_frequencies[attribute][value] += 1

    category_data_3[category] = (key_frequencies, value_frequencies, len(characteristics_series.dropna()))

# Выводим результат (если нужно)
# print(category_data_3)

# %%
category_data_3.keys()
# Out:
# dict_keys(['Одежда', 'БДСМ', 'Корма и лакомства для кошек и собак', 'Расходники для инструмента', 'Пенал', 'Соль, сахар, специи', 'Автозапчасти', 'Очки для зрения', 'Столовая посуда', 'Повседневная обувь', 'Печатные книги, журналы, комиксы', 'Аксессуары', 'Набор для рукоделия, творчества', 'Компьютерные и офисные кресла', 'Посуда для животных', 'Аксессуары и принадлежности для рыбалки', 'Белье', 'Щетки стеклоочистителя', 'Декоративная косметика', 'Бижутерные украшения', 'Игрушки', 'Декор и интерьер', 'Матрасы', 'Одежда и аксессуары эротические', 'Папки и файлы', 'Лодки и лодочные моторы', 'Мебель для ванной', 'Полотенца и скатерти', 'Бумажная продукция', 'Спецодежда', 'Коврики для мыши', 'Автомагнитолы', 'Экипировка и защита', 'Вытяжки', 'Смесители и душевые системы', 'Ковры и ковровые дорожки', 'Интимная косметика', 'Водонагреватели', 'Комоды и тумбы', 'Спортивная одежда', 'Моющие и чистящие средства', 'Кабели и переходники', 'Запчасти для смартфонов', 'Строительные смеси', 'Ортопедия, бандажи, компрессионные изделия, протезирование', 'Секс игрушки', 'Материал для рукоделия', 'Измерительный инструмент', 'Конструкторы', 'Пледы и покрывала', 'Аксессуары для игровых приставок', 'Светильники и аксессуары', 'Шкафы', 'Железные дороги', 'Электродрели', 'Семена и саженцы', 'Часы', 'Садовая мебель', 'Настольные и карточные игры', "(don't use) Галантерея", 'Холодильники', 'Постельное белье', 'Электроустановочные изделия', 'Лыжи и сноуборды', 'Спортивная и рабочая обувь', 'Инструмент для рукоделия', 'Товары для полива', 'Инструменты для ремонта и строительства', 'Аксессуары и запчасти для бытовой техники', 'Расходные материалы для печати', 'Строительная химия', 'Сухие завтраки, снэки, суперфудс', 'Диваны и кресла', 'Насосы для дачи', 'Сувениры и подарки', 'Стулья, скамьи, табуреты, пуфики', 'Соки, воды, напитки', 'Средства для гигиены полости рта', 'Фитнес-браслеты и кардиомониторы', 'Товар для ухода за животными', 'Рюкзаки, чехлы, сумки', 'Автоаксессуары и принадлежности', 'Косметика для ухода', 'Оптические приборы', 'Микроволновые печи', 'Автомобильные масла', 'Оборудование для торговли', 'Шторы и карнизы', 'Письменные принадлежности', 'Плиты', 'Кулеры для воды', 'Обучающие игры', 'Средства для гигиены тела', 'Лампочка', 'Средства по уходу за бровями и ресницами', 'Одежда и обувь для животных', 'Коляски и аксессуары к ним', 'Климатическая техника', 'Детский транспорт', 'Электрика', 'Аксессуары для волос', 'Средства от вредителей', 'Косметика для ухода за волосами', 'Компьютеры', 'Смарт-часы', 'Кузовные запчасти', 'Электрические чайники и термопоты', 'Радиоуправляемые игрушки', 'Аксессуары для туризма', 'Велосипеды, беговелы и самокаты', 'Пазлы, модели для сборки', 'Стол', 'Аксессуар для прогулки и дрессировки', 'Фонари и аксессуары', 'Фены и термощетки', 'Парфюмерия', 'Сантехника', 'Оперативная память', 'Окна и комплектующие к окнам', 'Туристическая посуда', 'Домофоны', 'Теплый пол', 'Оснастка для инструмента', 'Кабели и провод', 'Канцелярия', 'Лекарственные средства', 'Аксессуары для ремонта', "(don't use) Средства для ухода за обувью, одеждой", 'БАДы', 'Контактные линзы и средства для ухода', 'Кровати', 'Мониторы и запчасти', 'Медицинские расходные материалы', 'Маски и очки', 'Хранение вещей', 'Шины', 'Нитки, пряжа', 'Аксессуары для цветов', 'Палатки, тенты, шатры и спальные мешки', 'Наушники и гарнитуры', 'Ароматы для дома', 'Швейные машины', 'Товары для праздников', 'Миксеры, блендеры, измельчители', 'Грунт, удобрения и садовая химия', 'Линзы контактные, для очков, коррегирующие очки', 'Макароны, крупы, мука', 'Прикормки, ароматизаторы, насадки', 'Ручки, замки и фурнитура', 'Санфаянс и ванны', 'Водосточные системы', 'Мотоэкипировка', 'Материнские платы', 'Зарядные устройства и док-станции', 'Автохимия и автокосметика', 'Антенны и аксессуары', 'Устройства для стрижки волос и аксессуары', 'Запчасти для ноутбуков', 'Фильтры для воды', 'Санки, снегокаты, тюбинги', 'Ветаптека (расходные материалы)', 'Термосы, термокружки и сифоны для г ...

# %%
category_data_4 = {}

for category in train_features_df["cat_level_4_1"].unique():
    filtered_df = attributes_df[attributes_df["cat_level_4"] == category]
    characteristics_series = filtered_df["characteristic_attributes_mapping"]
    
    key_frequencies = {}  # Словарь для подсчета частоты ключей
    value_frequencies = {}  # Словарь для подсчета частоты значений по ключам

    for characteristic_text in characteristics_series.dropna():  
        characteristic_data = json.loads(characteristic_text) 
        
        for attribute, values in characteristic_data.items():  
            if attribute not in key_frequencies:
                key_frequencies[attribute] = 0
            key_frequencies[attribute] += 1
            
            if attribute not in value_frequencies:
                value_frequencies[attribute] = {}
            
            for value in values:
                if value not in value_frequencies[attribute]:
                    value_frequencies[attribute][value] = 0
                value_frequencies[attribute][value] += 1

    category_data_4[category] = (key_frequencies, value_frequencies, len(characteristics_series.dropna()))

# Выводим результат (если нужно)
# print(category_data_4)

# %%
category_data_4.keys()
# Out:
# dict_keys(['Свитер, джемпер', 'Наручники и фиксаторы', 'Корм сухой', 'Бур, сверло, набор сверл', 'Пенал', 'Дрожжи', 'Основные автозапчасти', 'Коррегирующие очки', 'Тарелка', 'Кеды, слипоны, сникеры', 'Печатная книга: Проза других жанров', 'Рюкзак', 'Набор для творчества', 'Кресло компьютерное', 'Толстовка, худи, свитшот', 'Ботинки', 'Коврик под миску', 'Аксессуар для рыбалки', 'Купальник раздельный', 'Щетки стеклоочистителя для авто', 'Гель-лак', 'Брелок', 'Печатная книга: Развитие ребенка', 'Фигурки, наборы фигурок', 'Кроссовки', 'Трафарет для стен ', 'Корм консервированный', 'Тормозные колодки дисковые и барабанные', 'Серьги', 'Матрас', 'Эротическое белье', 'Папка', 'Якорь лодочный', 'Тумба с раковиной', 'Скатерть', 'Ежедневник, еженедельник', 'Одежда для охоты и рыбалки', 'Пирсинг', 'Браслет', 'Коврик для мыши', 'Наручные часы', 'Босоножки', 'Автомагнитола', 'Чемодан', 'Шапочка для плавания', 'Вытяжки', 'Алмазная мозаика', 'Скрытая монтажная часть', 'Ковер', 'Возбуждающее средство', 'Трусы', 'Печатная книга: Психология, саморазвитие', 'Легинсы', 'Рабочая одежда', 'Водонагреватель накопительный', 'Печатная книга: Бизнес-литература', 'Тумба для обуви', 'Брюки спортивные', 'Кондиционер, ополаскиватель', 'Кабель', 'Запчасти для телефонов', 'Добавка в раствор', 'Корсеты, корректоры, бандажи, ортезы', 'Плаг (пробка)', 'Украшение декоративное', 'Лазерный уровень/нивелир', 'Конструктор', 'Плед', 'Подставка для консоли', 'Кольцо', 'Светильник для дома', 'Шкаф распашной', 'Железная дорога', 'Печатная книга: Досуг и творчество детей', 'Печатная книга: Пособие для школы', 'Скетчбук', 'Шуруповерт', 'Семена', 'Часы настенные', 'Комплект мебели для сада', 'Головоломка', 'Автозапчасти подвески', 'Кошелек', 'Стеклярус, бусины, стразы', 'Холодильник', 'Туфли', 'Стиральный порошок', 'Сумка дорожная', 'Комплект верхней одежды', 'Комплект постельного белья', 'Брюки', 'Футболка', 'Розетка', 'Сноуборд', 'Обувь для рыбалки и охоты', 'Носки, комплект носков', 'Блокнот, записная и телефонная книжка', 'Спицы для вязания', 'Шланг поливочный', 'Сумка на плечо', 'Куртка', 'Ключ', 'Мягкая игрушка', 'Аксессуары и запчасти для пылесосов', 'Сапоги', 'Картридж', 'Краски и эмали', 'Средство для мытья посуды', 'Сухофрукты', 'Диван', 'Печатная книга: Научная и научно-популярная литература', 'Насос поверхностный', 'Продукция сувенирная', 'Табурет', 'Сок и нектар', 'Зубная паста', 'Галоши', 'Велокомпьютер', 'Круг для электроинструмента', 'Лоток для животных', 'Сумка/рюкзак для ноутбука', 'Автоаксессуар', 'Тоник для лица', 'Микроскоп', 'Мастурбатор', 'Микроволновая печь', 'Игрушечное оружие', 'Моторное масло', 'Чехол на мебель', 'Шапка', 'БДСМ Одежда', 'Ремень', 'Информационные держатели', 'Комплект штор', 'Печатная книга: Фэнтези', 'Шлепанцы, сланцы', 'Ручка', 'Саженец, рассада', 'Духовой шкаф', 'Антистрессовая игрушка', 'Блесна', 'Печатная книга: Пособие для изучения иностранных языков', 'Кулеры для воды', 'Азартные игры', 'Обучающая игра', 'Платье', 'Выключатель', 'Головной убор для охоты и рыбалки', 'Плетеный шнур', 'Печатная книга: Книга для чтения на иностранном языке', 'Твердое мыло туалетное', 'Лампочка', 'Мыло для стирки', 'Краска для бровей и ресниц', 'Подвеска/кулон', 'Платок', 'Печатная книга: Религия', 'Одежда для животных', 'Коляска прогулочная', 'Чай листовой', 'Настольная игра', 'Увлажнитель воздуха', 'Каталка', 'Удлинитель строительный', 'Резинка для волос', 'Качели садовые', 'Средство от насекомых', 'Набор для вышивания', 'Бюстгальтер', 'Велотуфли', 'Краска для волос', 'Пододеяльник', 'Системный блок', 'Тапочки', 'Жидкое средство для стирки', 'Умные часы', 'Крыло автомобильное', 'Электрический чайник', 'Очиститель воздуха', 'Кукла', 'Машинка радиоуправляемая', 'Сумка/рюкзак для фото- видеотехники', 'Аксессуары для туризма и путешествий', 'Детские и трехколесные велосипеды', 'Леска для рыбалки', 'Универсальное чистящее средство', 'Средство для посудомоечных машин', 'Обложка для документов', 'Брюки утепленные', 'Пазл', 'Эрекционное кольцо', 'Набор  ...

# %% [markdown]
# ### Let's check how many different categories we have for each level

# %%
#attributes_df['categories'] = attributes_df['categories']
unique_categories_by_level = {}
for categories in attributes_df['categories']:
    if isinstance(categories, str):  
        categories = ast.literal_eval(categories)
    for level, category in categories.items():
        if level not in unique_categories_by_level:
            unique_categories_by_level[level] = set()
        unique_categories_by_level[level].add(category)
for level, categories in unique_categories_by_level.items():
    print(f"Level {level}: {len(categories)} unique categories")
# Out:
# Level 1: 3 unique categories
# Level 2: 24 unique categories
# Level 3: 583 unique categories
# Level 4: 3686 unique categories

# %%
train_features_df.shape
# Out:
# (1168516, 37)

# %%
X_train_val_df, X_test_df = train_test_split(
    train_features_df, 
    test_size=0.02, 
    stratify=train_features_df[['cat_level_1_1', 'target']]
#     stratify=train_df[['cat_level_2_1', 'target']]
)
X_train_val_df.shape, X_test_df.shape
# Out:
# ((1145145, 41), (23371, 41))

# %%
X_test_df.head().columns
# Out:
# Index(['variantid1', 'variantid2', 'target', 'categories1',
#        'characteristic_attributes_mapping1', 'cat_level_11', 'cat_level_21',
#        'cat_level_31', 'cat_level_41', 'categories2',
#        'characteristic_attributes_mapping2', 'cat_level_12', 'cat_level_22',
#        'cat_level_32', 'cat_level_42', 'name1', 'description1',
#        'name_bert_641', 'name2', 'description2', 'name_bert_642',
#        'main_pic_embeddings_resnet_v11', 'pic_embeddings_resnet_v11',
#        'main_pic_embeddings_resnet_v12', 'pic_embeddings_resnet_v12',
#        'cat_level_1_1', 'cat_level_2_1', 'cat_level_3_1', 'cat_level_4_1',
#        'cat_level_1_2', 'cat_level_2_2', 'cat_level_3_2', 'cat_level_4_2',
#        'is_equal_cat_1', 'is_equal_cat_2', 'is_equal_cat_3', 'is_equal_cat_4',
#        'main_pic_distance', 'text_distance_cos', 'text_distance_euc',
#        'text_distance_man'],
#       dtype='object')

# %%
features_columns = [
    'cat_level_1_1', 'cat_level_2_1', 'cat_level_3_1', 'cat_level_4_1',  
    'main_pic_embeddings_resnet_v11', 'pic_embeddings_resnet_v11', 'main_pic_embeddings_resnet_v12', 'pic_embeddings_resnet_v12',  
    'is_equal_cat_1', 'is_equal_cat_2', 'is_equal_cat_3', 'is_equal_cat_4',
    "main_pic_distance", "text_distance_cos", "text_distance_euc", "text_distance_man"
]

# %%
def plot_feature_importance(importance, names, model_name="", top_n=-1, skip_columns=None):
    skip_columns = skip_columns or []
    
    fi_df = pd.DataFrame({
        'feature_names': names,
        'feature_importance': importance
    })

    fi_df = fi_df[~fi_df['feature_names'].isin(skip_columns)]
    
    fi_df = fi_df.sort_values(by='feature_importance', ascending=False)
    
    if top_n != -1:
        fi_df = fi_df.head(top_n)
    
    plt.figure(figsize=(10, 8))
    sns.barplot(x='feature_importance', y='feature_names', data=fi_df, palette="viridis")
    
    title = f"{model_name} FEATURE IMPORTANCE"
    if top_n != -1:
        title += f" (Top: {top_n})"
    plt.title(title)
    plt.xlabel('FEATURE IMPORTANCE')
    plt.ylabel('FEATURE NAMES')
    plt.tight_layout()
    plt.show()
    
    return fi_df

# %% [markdown]
# Model for category 1

# %%
def train_test_split_by_cat(full_df, cat_name:str):
    full_df = full_df[full_df['cat_level_1_1'] == cat_name]
    X_train_df, X_val_df = train_test_split(
        full_df, 
        test_size=0.05, 
        stratify=full_df["target"]
    )
    # X_train_df = full_df
    return X_train_df, X_val_df

models_by_cat = {}
for cat_name in train_features_df["cat_level_1_1"].unique():
    print(cat_name)
    model = CatBoostClassifier(iterations=1000,
                    eval_metric =  "AUC", 
                    early_stopping_rounds=500, 
                    ignored_features=['variantid1', 'variantid2'],
                    cat_features=category_data_1,
                    # od_type = "Iter",
                    # od_wait = 200,                               
                    random_state=53,
                    task_type="CPU",
                    learning_rate = 0.1
                    )  
    
    X_train_df, X_val_df = train_test_split_by_cat(full_df=X_train_val_df, cat_name=cat_name)
    target_column = 'target'

    X_train = X_train_df[features_columns]
    y_train = X_train_df[target_column]

    X_val = X_val_df[features_columns]
    y_val = X_val_df[target_column]
    
    model.fit(X_train, y_train,
              eval_set=(X_val, y_val), 
              plot=True, 
              verbose=True 
             )
    
    plot_feature_importance(model.get_feature_importance(), (features_columns ),'CATBOOST ', top_n=10)
    plt.show()
    models_by_cat[cat_name] = model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 12
#       9     return X_train_df, X_val_df
#      11 models_by_cat = {}
# ---> 12 for cat_name in train_features_df["cat_level_1_1"].unique():
#      13     print(cat_name)
#      14     # Определяем модель
#
# NameError: name 'train_features_df' is not defined
